# %%
import pyarrow.parquet as pq

table = pq.read_table("current_2026-04-10T19-08-55Z_20260410T190905Z.parquet")
df = table.to_pandas()

df.to_csv("test.csv")

# %%
#day_ahead_total_load_forecast_2026-04-22T18-30-30Z_20260422T183134Z.parquet

import pyarrow.parquet as pq

table = pq.read_table("actual_generation_per_production_type_2026-04-22T18-30-30Z_20260422T183243Z.parquet")
df = table.to_pandas()
df.to_csv("test.csv")
